# %%
# head, tail 모두 가짐
# 각 노드는 앞 노드와 뒤 노드 정보를 모두 저장
# 리스트의 앞 혹은 뒤에서 모두 접근 가능

# 오름차순으로 데이터를 저장하는 양방향 연결 리스트

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 삭제
# 삽입 및 삭제에서 예외 사항 처리 필요
# 더 삭제할 원소가 없는데 삭제하는 경우 등 처리

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

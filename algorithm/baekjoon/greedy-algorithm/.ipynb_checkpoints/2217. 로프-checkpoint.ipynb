# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N, weights = int(input()), list()

ropes = [int(input()) for _ in range(N)]
ropes.sort(reverse=True)

for _ in range(N):
    min_weight = ropes.pop()
    weights.append(min_weight * N)
    N -= 1

max(weights)
# Out:
# 2
# 10
# 15
# 20

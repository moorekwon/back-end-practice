# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = int(input())
cnt = []

for a in range(divmod(N, 3)[0]+1):
    for b in range(divmod(N, 3)[0]+1):
        if 3*a + 5*b == N:
            cnt.append(a+b)

if not cnt:
    print(-1)
else:
    print(min(cnt))
# Out:
# 11
# 3

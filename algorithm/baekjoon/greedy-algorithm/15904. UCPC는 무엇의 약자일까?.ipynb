# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N = str(input())

output = ''
        
for syllable in N:
    if syllable.isupper():
        output += syllable

print('output >> ', output)
        
if output == 'UCPC':
    print('I love UCPC')
else:
    print('I hate UCPC')
# Out:
# University CPC
# output >>  UCPC
# I love UCPC

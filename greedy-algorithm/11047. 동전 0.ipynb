# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
N, A, output_lst = list(map(int, input().split())), list(), list()

for i in range(N[0]):
    A.insert(0, int(input()))    

for i, money in enumerate(A):
    while money <= N[1]:
        div = divmod(N[1], money)
        output_lst.append(div[0])
        N[1] = div[1]
        if N[1] > 0: continue
print(sum(output_lst))
# Out:
# 10 4200
# 1
# 5
# 10
# 50
# 100
# 500
# 1000
# 5000
# 10000
# 50000
# 6

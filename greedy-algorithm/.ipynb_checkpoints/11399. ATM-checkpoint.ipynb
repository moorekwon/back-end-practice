# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = int(input())
time = sorted(list(map(int, input().split())))
time_lst = list()

for each_time in time:
    num_time = each_time * num
    time_lst.append(num_time)
    num -= 1

print(sum(time_lst))
# Out:
# 5
# 3 6 4 2 8
# 54
